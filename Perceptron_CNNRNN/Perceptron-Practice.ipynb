# %% [markdown]
# ## 단층 Perceptron AND Gate 학습(Activation Function 없이 간략화)

# %% [markdown]
# **Wt+1=Wt −𝛼∇𝐿(𝑊𝑡) 공식을 이용해서 weight와 bias 학습**

# %% [markdown]
# ![2 input, 1 output 학습](And_Gate.png)

# %% [markdown]
# **1. Training Set X,Y 설정**

# %%
    X = [
        [0, 0],
        [0, 1],
        [1, 0],
        [1, 1]
    ]
    Y = [0, 0, 0, 1]

# %% [markdown]
# **2. Hypter Parameter 설정(learning rate, epochs 등)**

# %%
import random
import math
weights = [random.uniform(-1, 1) for _ in range(2)]
bias = random.uniform(-1, 1)
learning_rate = 0.01
epochs=5000

# %% [markdown]
# **3. 출력 예측 함수 작성**

# %%
def predict(inputs):
    """출력 예측 (순전파)"""
    return 작성할 것

# %% [markdown]
# **4. (출력-타겟) 오차를 계산하고 weight_new=weight_old - 학습률*error*입력 공식으로 weight 업데이트**

# %%
for epoch in range(epochs):
    total_error=0
    for inputs,label in zip(X,Y):
        작성할것
        출력값 예측하고
        출력값과 Target값과의 Error를 계산하고
        Weight와 bias를 업데이트
        Loss를 계산(error**2)
        ....
        
        # 1000회마다 오차 출력
    if epoch % 1000 == 0:
        print(f"Epoch {epoch}: Loss = {total_error / len(X):.4f}")
        print(weights, bias)
# Out:
# Epoch 0: Loss = 0.3347
# [0.2873492695926754, 0.5241356463040219] 0.3343090070184523
# Epoch 1000: Loss = 0.0638
# [0.5045832607226033, 0.5020655105309767] -0.2519686967934424
# Epoch 2000: Loss = 0.0638
# [0.5050496805411616, 0.5025244242497849] -0.25252426023093466
# Epoch 3000: Loss = 0.0638
# [0.5050505035808229, 0.5025252510481519] -0.25252525075607235
# Epoch 4000: Loss = 0.0638
# [0.5050505050478846, 0.5025252525226191] -0.2525252525220982

# %% [markdown]
# **5. 학습 결과 검증**

# %%
print("\n--- 학습 결과 테스트 ---")
for inputs in X:
    result = predict(inputs)
    print(f"입력: {inputs}, 예측값: {result:.4f} -> 결과: {1 if result >= 0.5 else 0}")
# Out:
# --- 학습 결과 테스트 ---
# 입력: [0, 0], 예측값: -0.2525 -> 결과: 0
# 입력: [0, 1], 예측값: 0.2500 -> 결과: 0
# 입력: [1, 0], 예측값: 0.2525 -> 결과: 0
# 입력: [1, 1], 예측값: 0.7551 -> 결과: 1
